# %%
from bs4 import BeautifulSoup
from nltk.util import ngrams
from collections import defaultdict
from nltk import trigrams
from nltk.tokenize import RegexpTokenizer
import requests

# %%
# load text from blog
response = requests.get("https://maxsiollun.wordpress.com/great-speeches-in-nigerias-history/")

# %%
# parse html and take only paragraph contents
soup = BeautifulSoup(response.text,'html.parser')
sentence = soup.find_all('p',text=True)

# %%
print(len(sentence))
# Out:
# 511

# %%
# marge all string lines into single line string
note=''
for line in sentence[50:100]:
    note+=str(line)

# %%
# convert text to lower case
sentence=note.lower()

# %%
# convert sentence into tokens and extract all punctuations
tokenizer = RegexpTokenizer(r'\w+')
tk_sentence=tokenizer.tokenize(sentence)
tk_sentence
# Out:
# ['p',
#  'on',
#  'this',
#  'occasion',
#  'i',
#  'wish',
#  'to',
#  'place',
#  'on',
#  'record',
#  'the',
#  'nation',
#  's',
#  'gratitude',
#  'to',
#  'the',
#  'organization',
#  'of',
#  'african',
#  'unity',
#  'for',
#  'its',
#  'splendid',
#  'diplomatic',
#  'and',
#  'moral',
#  'support',
#  'for',
#  'the',
#  'federal',
#  'cause',
#  'i',
#  'thank',
#  'particularly',
#  'the',
#  'chairman',
#  'of',
#  'the',
#  'consultative',
#  'committee',
#  'on',
#  'nigeria',
#  'his',
#  'imperial',
#  'majesty',
#  'haile',
#  'selassie',
#  'i',
#  'and',
#  'the',
#  'other',
#  'members',
#  'of',
#  'the',
#  'committee',
#  'i',
#  'also',
#  'thank',
#  'the',
#  'president',
#  'of',
#  'the',
#  'oau',
#  'general',
#  'assembly',
#  'presidents',
#  'mobutu',
#  'boumedienne',
#  'and',
#  'ahidjo',
#  'who',
#  'presided',
#  'over',
#  'oau',
#  'summit',
#  'discussions',
#  'of',
#  'the',
#  'nigerian',
#  'crisis',
#  'the',
#  'enemies',
#  'of',
#  'africa',
#  'were',
#  'restrained',
#  'by',
#  'the',
#  'demonstration',
#  'of',
#  'such',
#  'solid',
#  'support',
#  'i',
#  'thank',
#  'the',
#  'secretary',
#  'general',
#  'of',
#  'the',
#  'united',
#  'nations',
#  'u',
#  'thant',
#  'for',
#  'his',
#  'understanding',
#  'attitude',
#  'towards',
#  'our',
#  'country',
#  's',
#  'crisis',
#  'and',
#  'the',
#  'specialized',
#  'agencies',
#  'for',
#  'their',
#  'assistance',
#  'i',
#  'also',
#  'thank',
#  'the',
#  'friendly',
#  'governments',
#  'who',
#  'gave',
#  'us',
#  'moral',
#  'and',
#  'material',
#  'support',
#  'in',
#  'the',
#  'darkest',
#  'hour',
#  'of',
#  'our',
#  'need',
#  'the',
#  'nation',
#  'will',
#  'remember',
#  'them',
#  'as',
#  'true',
#  'friends',
#  'it',
#  'is',
#  'the',
#  'desire',
#  'of',
#  'my',
#  'government',
#  'that',
#  'our',
#  'relations',
#  'with',
#  'them',
#  'should',
#  'grow',
#  'stronger',
#  'p',
#  'p',
#  'consistent',
#  'with',
#  'our',
#  'basic',
#  'policy',
#  'we',
#  'shall',
#  'maintain',
#  'correct',
#  'relations',
#  'with',
#  'all',
#  'foreign',
#  'governments',
#  'notwithstanding',
#  'the',
#  'anxieties',
#  'they',
#  'may',
#  'have',
#  'caused',
#  'us',
#  'as',
#  'we',
#  'emerge',
#  'from',
#  'our',
#  'greatest',
#  'trial',
#  'we',
#  'shall',
#  'endeavour',
#  'to',
#  'work',
#  'for',
#  'peace',
#  'in',
#  'the',
#  'world',
#  'and',
#  'for',
#  'a',
#  'better',
#  'economic',
#  'deal',
#  'for',
#  'the',
#  'less',
#  'developed',
#  'countries',
#  'of',
#  'the',
#  'world',
#  'p',
#  'p',
#  'the',
#  'armed',
#  'forces',
#  'deserve',
#  'the',
#  'greatest',
#  'praise',
#  'for',
#  'their',
#  'valour',
#  'in',
#  'battle',
#  'their',
#  'loyalty',
#  'and',
#  'dedication',
#  'and',
#  'for',
#  'their',
#  'resourcefulness',
#  'in',
#  'overcoming',
#  'the',
#  'formidable',
#  'obstacles',
#  'placed',
#  'in',
#  'our',
#  'way',
#  'i',
#  'praise',
#  'them',
#  'for',
#  'observing',
#  'strictly',
#  'the',
#  'code',
#  'of',
#  'conduct',
#  'issued',
#  'to',
#  'them',
#  'at',
#  'the',
#  'beginning',
#  'of',
#  'the',
#  'operations',
#  'it',
#  'is',
#  'necessary',
#  'now',
#  'more',
#  'than',
#  'ever',
#  'when',
#  'the',
#  'rebellion',
#  'is',
#  'ended',
#  'for',
#  'them',
#  'to',
#  'maintain',
#  'the',
#  'high',
#  'standard',
#  'they',
#  'have',
#  'attained',
#  'the',
#  'letter',
#  'and',
#  'spirit',
#  'of',
#  'the',
#  'code',
#  'must',
#  'be',
#  'obeyed',
#  'their',
#  'first',
#  'duty',
#  'is',
#  'to',
#  'protect',
#  'the',
#  'lives',
#  'and',
#  'property',
#  'of',
#  'all',
#  'surrendering',
#  'troops',
#  'and',
#  'civilians',
#  'and',
#  'to',
#  'give',
#  'them',
#  'humane',
#  'treatment',
#  'stern',
#  'disciplinary',
#  'measures',
#  'will',
#  'be',
#  'taken',
#  'against',
#  'any',
#  'who',
#  'violate',
#  'the',
#  'code',
#  'i',
#  'know',
#  'however',
#  'that',
#  'i',
#  'can',
#  'continue',
#  'to',
#  'count',
#  'on',
#  'your',
#  'loyalty',
#  'and',
#  'discipline',
#  'p',
#  'p',
#  'i',
#  'also',
#  'praise',
#  'the',
#  'civilian',
#  'population',
#  'everywhere',
#  'in',
#  'the',
#  'country',
#  'for',
#  'their',
#  'patience',
#  'sacrifice',
#  'loyalty',
#  'and',
#  'steadfast',
#  'support',
#  'for',
#  'the',
#  'fighting',
#  'troops',
#  'and',
#  'for',
#  'one',
#  'nigeria',
#  'we',
#  'must',
#  'all',
#  'be',
#  'justly',
#  'proud',
#  'all',
#  'nigerians',
#  'share',
#  'the',
#  'victory',
#  'of',
#  'today',
#  'the',
#  'victory',
#  'for',
#  'national',
#  'unity',
#  'victory',
#  'for',
#  'hopes',
#  'of',
#  'africans',
#  'and',
#  'black',
#  'people',
#  'everywhere',
#  'we',
#  'must',
#  'thank',
#  'god',
#  'for',
#  'his',
#  'mercies',
#  'we',
#  'mourn',
#  'the',
#  'dead',
#  'heroes',
#  'we',
#  'thank',
#  'god',
#  'for',
#  'sparing',
#  'us',
#  'to',
#  'see',
#  'his',
#  'glorious',
#  'dawn',
#  'of',
#  'national',
#  'reconciliation',
#  'we',
#  'have',
#  'ordered',
#  'that',
#  'friday',
#  'saturday',
#  'and',
#  'sunday',
#  'be',
#  'national',
#  'days',
#  'of',
#  'prayer',
#  'we',
#  'must',
#  'his',
#  'guidance',
#  'to',
#  'do',
#  'our',
#  'duty',
#  'to',
#  'contribute',
#  'our',
#  'quota',
#  'to',
#  'the',
#  'building',
#  'of',
#  'a',
#  'great',
#  'nation',
#  'founded',
#  'on',
#  'the',
#  'concerted',
#  'efforts',
#  'of',
#  'all',
#  'its',
#  'people',
#  'and',
#  'on',
#  'justice',
#  'and',
#  'equality',
#  'a',
#  'nation',
#  'never',
#  'to',
#  'return',
#  'to',
#  'the',
#  'fractious',
#  'sterile',
#  'and',
#  'selfish',
#  'debates',
#  'that',
#  'led',
#  'to',
#  'the',
#  'tragic',
#  'conflict',
#  'just',
#  'ending',
#  'we',
#  'have',
#  'overcome',
#  'a',
#  'lot',
#  'over',
#  'the',
#  'past',
#  'four',
#  'years',
#  'i',
#  'have',
#  'therefore',
#  'every',
#  'confidence',
#  'that',
#  'ours',
#  'will',
#  'become',
#  'a',
#  'great',
#  'nation',
#  'so',
#  'help',
#  'us',
#  'god',
#  'p',
#  'p',
#  'long',
#  'live',
#  'the',
#  'federal',
#  'republic',
#  'of',
#  'nigeria',
#  'p',
#  'p',
#  'strong',
#  'span',
#  'style',
#  'text',
#  'decoration',
#  'underline',
#  'statement',
#  'at',
#  'dodan',
#  'barracks',
#  'on',
#  'january',
#  '15',
#  '1970',
#  'by',
#  'major',
#  'general',
#  'phillip',
#  'efiong',
#  'officer',
#  'administering',
#  'the',
#  'republic',
#  'of',
#  'biafra',
#  'span',
#  'strong',
#  'p',
#  'p',
#  'i',
#  'major',
#  'general',
#  'phillip',
#  'efiong',
#  'officer',
#  'administering',
#  'the',
#  'government',
#  'of',
#  'the',
#  'republic',
#  'of',
#  'biafra',
#  'now',
#  'wish',
#  'to',
#  'make',
#  'the',
#  'following',
#  'declaration',
#  'p',
#  'p',
#  'that',
#  'we',
#  'affirm',
#  'that',
#  'we',
#  'are',
#  'loyal',
#  'nigerian',
#  'citizens',
#  'and',
#  'accept',
#  'the',
#  'authority',
#  'of',
#  'the',
#  'federal',
#  'military',
#  'government',
#  'of',
#  'nigeria',
#  'p',
#  'p',
#  'that',
#  'we',
#  'accept',
#  'the',
#  'existing',
#  'administrative',
#  'and',
#  'political',
#  'structure',
#  'of',
#  'the',
#  'federation',
#  'of',
#  'nigeria',
#  'p',
#  'p',
#  'that',
#  'any',
#  'future',
#  'constitutional',
#  'arrangement',
#  'will',
#  'be',
#  'worked',
#  'out',
#  'by',
#  'representatives',
#  'of',
#  'the',
#  'people',
#  'of',
#  'nigeria',
#  'p',
#  'p',
#  'that',
#  'the',
#  'republic',
#  'of',
#  'biafra',
#  'hereby',
#  'ceases',
#  'to',
#  'exist',
#  'p',
#  'p',
#  'strong',
#  'span',
#  'style',
#  'text',
#  'decoration',
#  'underline',
#  'general',
#  'gowon',
#  'is',
#  'overthrown',
#  'maiden',
#  'speech',
#  'of',
#  'brigadier',
#  'murtala',
#  'ramat',
#  'muhammed',
#  'july',
#  '29',
#  '1975',
#  'span',
#  'strong',
#  'p',
#  'p',
#  'fellow',
#  'nigerians',
#  'events',
#  'of',
#  'the',
#  'past',
#  'few',
#  'years',
#  'have',
#  'indicated',
#  'that',
#  'despite',
#  'our',
#  'great',
#  'human',
#  'and',
#  'material',
#  'resources',
#  'the',
#  'government',
#  'has',
#  'not',
#  'been',
#  'able',
#  'to',
#  'fulfill',
#  'the',
#  'legitimate',
#  'expectations',
#  'of',
#  'our',
#  'people',
#  'nigeria',
#  'has',
#  'been',
#  'left',
#  'to',
#  'drift',
#  'this',
#  'situation',
#  'if',
#  'not',
#  'arrested',
#  'would',
#  'inevitably',
#  'have',
#  'resulted',
#  'in',
#  'chaos',
#  'and',
#  'even',
#  'bloodshed',
#  'in',
#  'the',
#  'endeavour',
#  'to',
#  'build',
#  'a',
#  'strong',
#  'united',
#  'and',
#  'virile',
#  'nation',
#  'nigerians',
#  'have',
#  'shed',
#  'much',
#  'blood',
#  'the',
#  'thought',
#  'of',
#  'further',
#  'bloodshed',
#  'for',
#  'whatever',
#  'reasons',
#  'must',
#  'i',
#  'am',
#  'sure',
#  'be',
#  'revolting',
#  'to',
#  'our',
#  'people',
#  'the',
#  'armed',
#  'forces',
#  'having',
#  'examined',
#  'the',
#  'situation',
#  'came',
#  'to',
#  'the',
#  'conclusion',
#  'that',
#  'certain',
#  'changes',
#  'were',
#  'inevitable',
#  'after',
#  'the',
#  'civil',
#  'war',
#  'the',
#  'affairs',
#  'of',
#  'state',
#  'hitherto',
#  'a',
#  'collective',
#  'responsibility',
#  'became',
#  'characterized',
#  'by',
#  'lack',
#  'of',
#  'consultation',
#  'indecision',
#  'indiscipline',
#  'and',
#  'even',
#  'neglect',
#  'indeed',
#  'the',
#  'public',
#  'at',
#  'large',
#  'became',
#  'disillusioned',
#  'and',
#  'disappointed',
#  'by',
#  'these',
#  'developments',
#  'this',
#  'trend',
#  'was',
#  'clearly',
#  'incompatible',
#  'with',
#  'the',
#  'philosophy',
#  'and',
#  'image',
#  'of',
#  'a',
#  'corrective',
#  'regime',
#  'unknown',
#  'to',
#  'the',
#  'general',
#  'public',
#  'the',
#  'feeling',
#  'of',
#  'disillusionment',
#  'was',
#  'also',
#  'evident',
#  'among',
#  'members',
#  'of',
#  'the',
#  'armed',
#  'forces',
#  'whose',
#  'administration',
#  'was',
#  'neglected',
#  'but',
#  'who',
#  'out',
#  'of',
#  'sheer',
#  'loyalty',
#  'to',
#  'the',
#  'nation',
#  'and',
#  'in',
#  'the',
#  'hope',
#  'that',
#  'there',
#  'would',
#  'be',
#  'a',
#  'change',
#  'continued',
#  'to',
#  'suffer',
#  'in',
#  'silence',
#  'things',
#  'got',
#  'to',
#  'a',
#  'stage',
#  'where',
#  'the',
#  'head',
#  'of',
#  'administration',
#  'became',
#  'virtually',
#  'inaccessible',
#  'even',
#  'to',
#  'official',
#  'advisers',
#  'and',
#  'when',
#  'advice',
#  'was',
#  'tendered',
#  'it',
#  'was',
#  'often',
#  'ignored',
#  'responsible',
#  'opinion',
#  'including',
#  'advice',
#  'by',
#  'eminent',
#  'nigerians',
#  'traditional',
#  'rulers',
#  'intellectuals',
#  'et',
#  'cetera',
#  'was',
#  'similarly',
#  'discarded',
#  'the',
#  'leadership',
#  'either',
#  'by',
#  'design',
#  'or',
#  'default',
#  'had',
#  'become',
#  'too',
#  'insensitive',
#  'to',
#  'the',
#  'true',
#  'feelings',
#  'and',
#  'yearnings',
#  'of',
#  'the',
#  'people',
#  'the',
#  'nation',
#  'was',
#  'thus',
#  'plunged',
#  'inexorably',
#  'into',
#  'chaos',
#  'it',
#  'was',
#  'obvious',
#  'that',
#  'matters',
#  'could',
#  'not',
#  'and',
#  'should',
#  'not',
#  'be',
#  'allowed',
#  'in',
#  'this',
#  'manner',
#  'and',
#  'in',
#  'order',
#  'to',
#  'give',
#  'the',
#  'nation',
#  'a',
#  'new',
#  'lease',
#  'of',
#  'life',
#  'and',
#  'sense',
#  'of',
#  'direction',
#  'the',
#  'following',
#  'decisions',
#  'were',
#  'taken',
#  '1',
#  'the',
#  'removal',
#  'of',
#  'general',
#  'yakubu',
#  'gowon',
#  'as',
#  'head',
#  'of',
#  'the',
#  'federal',
#  'military',
#  'government',
#  'and',
#  'commander',
#  'in',
#  'chief',
#  'of',
#  'the',
#  'armed',
#  'forces',
#  '2',
#  'the',
#  ...]

# %%
# Create Word Model
word_model = defaultdict(lambda: defaultdict(lambda: 0))

for sentence in tk_sentence:
    for first_word, second_word, word_label in trigrams(tk_sentence,pad_left=True,pad_right=True):
        word_model[(first_word, second_word)][word_label] += 1
dict(word_model)
# Out:
# {(None, None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'p': 1559}),
#  (None, 'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'on': 1559}),
#  ('p', 'on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'this': 1559}),
#  ('on', 'this'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'occasion': 1559}),
#  ('this',
#   'occasion'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 1559}),
#  ('occasion', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'wish': 1559}),
#  ('i', 'wish'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 1559}),
#  ('wish', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'make': 1559, 'place': 1559}),
#  ('to', 'place'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'on': 1559}),
#  ('place', 'on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'record': 1559}),
#  ('on', 'record'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('record', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'nation': 1559}),
#  ('the', 'nation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'3': 1559,
#               'a': 1559,
#               'and': 1559,
#               's': 1559,
#               'was': 1559,
#               'will': 1559}),
#  ('nation', 's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'gratitude': 1559}),
#  ('s',
#   'gratitude'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1559}),
#  ('gratitude',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('to', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'building': 1559,
#               'conclusion': 1559,
#               'country': 1559,
#               'fractious': 1559,
#               'general': 1559,
#               'nation': 3118,
#               'organization': 1559,
#               'tragic': 1559,
#               'true': 1559}),
#  ('the',
#   'organization'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('organization',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'african': 1559}),
#  ('of', 'african'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'unity': 1559}),
#  ('african',
#   'unity'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('unity', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'its': 1559}),
#  ('for', 'its'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'splendid': 1559}),
#  ('its',
#   'splendid'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'diplomatic': 1559}),
#  ('splendid',
#   'diplomatic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('diplomatic',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'moral': 1559}),
#  ('and', 'moral'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'support': 1559}),
#  ('moral',
#   'support'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('support',
#   'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 3118}),
#  ('for', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'federal': 1559, 'fighting': 1559, 'less': 1559}),
#  ('the',
#   'federal'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'cause': 1559,
#               'executive': 3118,
#               'level': 1559,
#               'military': 3118,
#               'republic': 1559}),
#  ('federal',
#   'cause'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 1559}),
#  ('cause', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'thank': 1559}),
#  ('i', 'thank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'particularly': 1559, 'the': 1559}),
#  ('thank',
#   'particularly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('particularly',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'chairman': 1559}),
#  ('the',
#   'chairman'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('chairman',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('of', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'armed': 6236,
#               'code': 1559,
#               'committee': 1559,
#               'consultative': 1559,
#               'country': 1559,
#               'federal': 3118,
#               'federation': 1559,
#               'new': 1559,
#               'nigerian': 1559,
#               'oau': 1559,
#               'operations': 1559,
#               'past': 1559,
#               'people': 3118,
#               'rank': 1559,
#               'republic': 1559,
#               'united': 1559,
#               'world': 1559}),
#  ('the',
#   'consultative'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'committee': 1559}),
#  ('consultative',
#   'committee'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'on': 1559}),
#  ('committee',
#   'on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'nigeria': 1559}),
#  ('on', 'nigeria'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'his': 1559}),
#  ('nigeria',
#   'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'imperial': 1559}),
#  ('his',
#   'imperial'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'majesty': 1559}),
#  ('imperial',
#   'majesty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'haile': 1559}),
#  ('majesty',
#   'haile'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'selassie': 1559}),
#  ('haile',
#   'selassie'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 1559}),
#  ('selassie', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 1559}),
#  ('i', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('and', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'administrator': 1559, 'other': 1559, 'specialized': 1559}),
#  ('the', 'other'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'members': 1559}),
#  ('other',
#   'members'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('members', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 4677}),
#  ('the',
#   'committee'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 1559}),
#  ('committee',
#   'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'also': 1559}),
#  ('i', 'also'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'praise': 1559, 'thank': 3118}),
#  ('also', 'thank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 3118}),
#  ('thank', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'friendly': 1559, 'president': 1559, 'secretary': 1559}),
#  ('the',
#   'president'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('president',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('the', 'oau'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'general': 1559}),
#  ('oau',
#   'general'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'assembly': 1559}),
#  ('general',
#   'assembly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'presidents': 1559}),
#  ('assembly',
#   'presidents'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'mobutu': 1559}),
#  ('presidents',
#   'mobutu'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'boumedienne': 1559}),
#  ('mobutu',
#   'boumedienne'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('boumedienne',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ahidjo': 1559}),
#  ('and', 'ahidjo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'who': 1559}),
#  ('ahidjo', 'who'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'presided': 1559}),
#  ('who',
#   'presided'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'over': 1559}),
#  ('presided',
#   'over'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'oau': 1559}),
#  ('over', 'oau'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'summit': 1559}),
#  ('oau', 'summit'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'discussions': 1559}),
#  ('summit',
#   'discussions'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('discussions',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('the',
#   'nigerian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'crisis': 1559}),
#  ('nigerian',
#   'crisis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('crisis', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'enemies': 1559}),
#  ('the',
#   'enemies'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('enemies', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'africa': 1559}),
#  ('of', 'africa'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'were': 1559}),
#  ('africa',
#   'were'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'restrained': 1559}),
#  ('were',
#   'restrained'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'by': 1559}),
#  ('restrained',
#   'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('by', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'demonstration': 1559}),
#  ('the',
#   'demonstration'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('demonstration',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'such': 1559}),
#  ('of', 'such'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'solid': 1559}),
#  ('such', 'solid'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'support': 1559}),
#  ('solid',
#   'support'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 1559}),
#  ('support', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'thank': 1559}),
#  ('the',
#   'secretary'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'general': 1559}),
#  ('secretary',
#   'general'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('general', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'police': 3118, 'police5': 1559, 'the': 1559}),
#  ('the', 'united'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'nations': 1559}),
#  ('united',
#   'nations'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'u': 1559}),
#  ('nations', 'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'thant': 1559}),
#  ('u', 'thant'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'for': 1559}),
#  ('thant', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'his': 1559}),
#  ('for', 'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'mercies': 1559, 'understanding': 1559}),
#  ('his',
#   'understanding'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'attitude': 1559}),
#  ('understanding',
#   'attitude'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'towards': 1559}),
#  ('attitude',
#   'towards'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 1559}),
#  ('towards',
#   'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'country': 1559}),
#  ('our',
#   'country'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'s': 1559}),
#  ('country', 's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'crisis': 1559}),
#  ('s', 'crisis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 1559}),
#  ('crisis', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('the',
#   'specialized'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'agencies': 1559}),
#  ('specialized',
#   'agencies'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('agencies',
#   'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'their': 1559}),
#  ('for', 'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'assistance': 1559,
#               'patience': 1559,
#               'resourcefulness': 1559,
#               'valour': 1559}),
#  ('their',
#   'assistance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 1559}),
#  ('assistance',
#   'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'also': 1559}),
#  ('the',
#   'friendly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'governments': 1559}),
#  ('friendly',
#   'governments'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'who': 1559}),
#  ('governments',
#   'who'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'gave': 1559}),
#  ('who', 'gave'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'us': 1559}),
#  ('gave', 'us'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'moral': 1559}),
#  ('us', 'moral'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 1559}),
#  ('moral', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'material': 1559}),
#  ('and',
#   'material'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'resources': 1559,
#               'support': 1559}),
#  ('material',
#   'support'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1559}),
#  ('support', 'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('in', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'country': 1559,
#               'darkest': 1559,
#               'endeavour': 1559,
#               'federal': 1559,
#               'hope': 1559,
#               'world': 1559}),
#  ('the',
#   'darkest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'hour': 1559}),
#  ('darkest',
#   'hour'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('hour', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'our': 1559}),
#  ('of', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'need': 1559, 'people': 1559}),
#  ('our', 'need'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('need', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'nation': 1559}),
#  ('nation',
#   'will'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'remember': 1559}),
#  ('will',
#   'remember'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'them': 1559}),
#  ('remember',
#   'them'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'as': 1559}),
#  ('them', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'true': 1559}),
#  ('as', 'true'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'friends': 1559}),
#  ('true',
#   'friends'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'it': 1559}),
#  ('friends', 'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'is': 1559}),
#  ('it', 'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'necessary': 1559, 'the': 1559}),
#  ('is', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'desire': 1559}),
#  ('the', 'desire'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 1559}),
#  ('desire', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'my': 1559}),
#  ('of', 'my'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'government': 1559}),
#  ('my',
#   'government'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'that': 1559}),
#  ('government',
#   'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 1559}),
#  ('that', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'relations': 1559}),
#  ('our',
#   'relations'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'with': 1559}),
#  ('relations',
#   'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'all': 1559,
#               'them': 1559}),
#  ('with', 'them'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'should': 1559}),
#  ('them',
#   'should'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'grow': 1559}),
#  ('should',
#   'grow'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'stronger': 1559}),
#  ('grow',
#   'stronger'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'p': 1559}),
#  ('stronger', 'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'p': 1559}),
#  ('p', 'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'10': 1559,
#               '11': 1559,
#               '12': 1559,
#               '1st': 1559,
#               '2nd': 1559,
#               '3rd': 1559,
#               '4': 1559,
#               '5': 1559,
#               '6': 1559,
#               '7': 1559,
#               '8': 1559,
#               '9': 1559,
#               'all': 1559,
#               'brigadier': 6236,
#               'captain': 3118,
#               'col': 1559,
#               'colonel': 4677,
#               'commodore': 1559,
#               'consistent': 1559,
#               'fellow': 1559,
#               'gocs': 1559,
#               'i': 4677,
#               'l': 1559,
#               'long': 1559,
#               'lt': 6236,
#               'mr': 3118,
#               'political': 1559,
#               'strong': 3118,
#               'that': 6236,
#               'the': 4677,
#               'there': 1559}),
#  ('p',
#   'consistent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'with': 1559}),
#  ('consistent',
#   'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 1559}),
#  ('with', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'basic': 1559}),
#  ('our', 'basic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'policy': 1559}),
#  ('basic',
#   'policy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 1559}),
#  ('policy', 'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'shall': 1559}),
#  ('we', 'shall'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'endeavour': 1559, 'maintain': 1559}),
#  ('shall',
#   'maintain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'correct': 1559}),
#  ('maintain',
#   'correct'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'relations': 1559}),
#  ('correct',
#   'relations'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'with': 1559}),
#  ('with', 'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'foreign': 1559}),
#  ('all',
#   'foreign'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'governments': 1559}),
#  ('foreign',
#   'governments'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'notwithstanding': 1559}),
#  ('governments',
#   'notwithstanding'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('notwithstanding',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'anxieties': 1559}),
#  ('the',
#   'anxieties'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'they': 1559}),
#  ('anxieties',
#   'they'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'may': 1559}),
#  ('they', 'may'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'have': 1559}),
#  ('may', 'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'caused': 1559}),
#  ('have',
#   'caused'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'us': 1559}),
#  ('caused', 'us'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'as': 1559}),
#  ('us', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'we': 1559}),
#  ('as', 'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'emerge': 1559}),
#  ('we', 'emerge'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'from': 1559}),
#  ('emerge',
#   'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 1559}),
#  ('from', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'greatest': 1559}),
#  ('our',
#   'greatest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'trial': 1559}),
#  ('greatest',
#   'trial'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 1559}),
#  ('trial', 'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'shall': 1559}),
#  ('shall',
#   'endeavour'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1559}),
#  ('endeavour',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'build': 1559,
#               'work': 1559}),
#  ('to', 'work'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'for': 1559}),
#  ('work', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'peace': 1559}),
#  ('for', 'peace'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'in': 1559}),
#  ('peace', 'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('the', 'world'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 1559, 'p': 1559}),
#  ('world', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'for': 1559}),
#  ('and', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'a': 1559, 'one': 1559, 'their': 1559}),
#  ('for', 'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'better': 1559}),
#  ('a', 'better'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'economic': 1559}),
#  ('better',
#   'economic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'deal': 1559}),
#  ('economic',
#   'deal'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('deal', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('the', 'less'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'developed': 1559}),
#  ('less',
#   'developed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'countries': 1559}),
#  ('developed',
#   'countries'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('countries',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('world', 'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'p': 1559}),
#  ('p', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'armed': 1559, 'head': 1559, 'structure': 1559}),
#  ('the', 'armed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'forces': 10913}),
#  ('armed',
#   'forces'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'2': 1559,
#               'are': 1559,
#               'deserve': 1559,
#               'having': 1559,
#               'in': 1559,
#               'p': 1559,
#               'whose': 1559}),
#  ('forces',
#   'deserve'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('deserve',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'greatest': 1559}),
#  ('the',
#   'greatest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'praise': 1559}),
#  ('greatest',
#   'praise'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('praise', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'their': 1559}),
#  ('their',
#   'valour'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1559}),
#  ('valour', 'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'battle': 1559}),
#  ('in', 'battle'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'their': 1559}),
#  ('battle',
#   'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'loyalty': 1559}),
#  ('their',
#   'loyalty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('loyalty',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'dedication': 1559,
#               'discipline': 1559,
#               'steadfast': 1559}),
#  ('and',
#   'dedication'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('dedication',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('their',
#   'resourcefulness'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1559}),
#  ('resourcefulness',
#   'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'overcoming': 1559}),
#  ('in',
#   'overcoming'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('overcoming',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'formidable': 1559}),
#  ('the',
#   'formidable'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'obstacles': 1559}),
#  ('formidable',
#   'obstacles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'placed': 1559}),
#  ('obstacles',
#   'placed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1559}),
#  ('placed', 'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'our': 1559}),
#  ('in', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'way': 1559}),
#  ('our', 'way'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'i': 1559}),
#  ('way', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'praise': 1559}),
#  ('i', 'praise'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'them': 1559}),
#  ('praise',
#   'them'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('them', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'observing': 1559}),
#  ('for',
#   'observing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'strictly': 1559}),
#  ('observing',
#   'strictly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('strictly',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'code': 1559}),
#  ('the', 'code'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'i': 1559, 'must': 1559, 'of': 1559}),
#  ('code', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'conduct': 1559}),
#  ('of', 'conduct'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'issued': 1559}),
#  ('conduct',
#   'issued'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1559}),
#  ('issued', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'them': 1559}),
#  ('to', 'them'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'at': 1559}),
#  ('them', 'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('at', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'beginning': 1559, 'federal': 1559, 'state': 1559}),
#  ('the',
#   'beginning'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('beginning',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('the',
#   'operations'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'it': 1559}),
#  ('operations',
#   'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'is': 1559}),
#  ('is',
#   'necessary'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'now': 1559}),
#  ('necessary',
#   'now'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'more': 1559}),
#  ('now', 'more'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'than': 1559}),
#  ('more', 'than'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'ever': 1559}),
#  ('than', 'ever'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'when': 1559}),
#  ('ever', 'when'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('when', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'rebellion': 1559}),
#  ('the',
#   'rebellion'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'is': 1559}),
#  ('rebellion',
#   'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ended': 1559}),
#  ('is', 'ended'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'for': 1559}),
#  ('ended', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'them': 1559}),
#  ('for', 'them'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 1559}),
#  ('them', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'maintain': 1559}),
#  ('to',
#   'maintain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('maintain',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'high': 1559}),
#  ('the', 'high'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'standard': 1559}),
#  ('high',
#   'standard'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'they': 1559}),
#  ('standard',
#   'they'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'have': 1559}),
#  ('they', 'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'attained': 1559}),
#  ('have',
#   'attained'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('attained',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'letter': 1559}),
#  ('the', 'letter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 1559}),
#  ('letter', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'spirit': 1559}),
#  ('and', 'spirit'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 1559}),
#  ('spirit', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('code', 'must'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'be': 1559}),
#  ('must', 'be'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'obeyed': 1559}),
#  ('be', 'obeyed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'their': 1559}),
#  ('obeyed',
#   'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'first': 1559}),
#  ('their',
#   'first'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'duty': 1559}),
#  ('first', 'duty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'is': 1559}),
#  ('duty', 'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 1559}),
#  ('is', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'protect': 1559}),
#  ('to', 'protect'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('protect',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'lives': 1559}),
#  ('the', 'lives'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 1559}),
#  ('lives', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'property': 1559}),
#  ('and',
#   'property'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('property',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'all': 1559}),
#  ('of', 'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'its': 1559, 'surrendering': 1559}),
#  ('all',
#   'surrendering'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'troops': 1559}),
#  ('surrendering',
#   'troops'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('troops', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'civilians': 1559, 'for': 1559}),
#  ('and',
#   'civilians'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('civilians',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1559}),
#  ('and', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'give': 1559}),
#  ('to', 'give'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559, 'them': 1559}),
#  ('give', 'them'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'humane': 1559}),
#  ('them',
#   'humane'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'treatment': 1559}),
#  ('humane',
#   'treatment'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'stern': 1559}),
#  ('treatment',
#   'stern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'disciplinary': 1559}),
#  ('stern',
#   'disciplinary'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'measures': 1559}),
#  ('disciplinary',
#   'measures'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'will': 1559}),
#  ('measures',
#   'will'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'be': 1559}),
#  ('will', 'be'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'announced': 1559,
#               'free': 3118,
#               'guaranteed': 1559,
#               'taken': 1559,
#               'worked': 1559}),
#  ('be', 'taken'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'against': 1559}),
#  ('taken',
#   'against'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'any': 1559}),
#  ('against',
#   'any'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'who': 1559}),
#  ('any', 'who'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'violate': 1559}),
#  ('who',
#   'violate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('violate',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'code': 1559}),
#  ('code', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'know': 1559}),
#  ('i', 'know'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'however': 1559}),
#  ('know',
#   'however'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'that': 1559}),
#  ('however',
#   'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 1559}),
#  ('that', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'can': 1559}),
#  ('i', 'can'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'continue': 1559}),
#  ('can',
#   'continue'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1559}),
#  ('continue',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'be': 1559,
#               'count': 1559}),
#  ('to', 'count'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'on': 1559}),
#  ('count', 'on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'your': 1559}),
#  ('on', 'your'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'loyalty': 1559}),
#  ('your',
#   'loyalty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('and',
#   'discipline'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'p': 1559}),
#  ('discipline',
#   'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'p': 1559}),
#  ('p', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'also': 1559, 'major': 1559, 'the': 1559}),
#  ('also',
#   'praise'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('praise', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'civilian': 1559}),
#  ('the',
#   'civilian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'population': 1559}),
#  ('civilian',
#   'population'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'everywhere': 1559}),
#  ('population',
#   'everywhere'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1559}),
#  ('everywhere',
#   'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('the',
#   'country'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'as': 1559,
#               'for': 1559,
#               'his': 1559}),
#  ('country',
#   'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'their': 1559}),
#  ('their',
#   'patience'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'sacrifice': 1559}),
#  ('patience',
#   'sacrifice'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'loyalty': 1559}),
#  ('sacrifice',
#   'loyalty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('and',
#   'steadfast'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'support': 1559}),
#  ('steadfast',
#   'support'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('the',
#   'fighting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'troops': 1559}),
#  ('fighting',
#   'troops'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('for', 'one'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'nigeria': 1559}),
#  ('one',
#   'nigeria'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 1559}),
#  ('nigeria', 'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'must': 1559}),
#  ('we', 'must'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'all': 1559, 'his': 1559, 'thank': 1559}),
#  ('must', 'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'be': 1559}),
#  ('all', 'be'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'justly': 1559}),
#  ('be', 'justly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'proud': 1559}),
#  ('justly',
#   'proud'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'all': 1559}),
#  ('proud', 'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'nigerians': 1559}),
#  ('all',
#   'nigerians'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'share': 1559}),
#  ('nigerians',
#   'share'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('share', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'victory': 1559}),
#  ('the',
#   'victory'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559,
#               'of': 1559}),
#  ('victory', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'today': 1559}),
#  ('of', 'today'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('today', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'victory': 1559}),
#  ('victory',
#   'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'hopes': 1559,
#               'national': 1559}),
#  ('for',
#   'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'unity': 1559}),
#  ('national',
#   'unity'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'victory': 1559}),
#  ('unity',
#   'victory'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 1559}),
#  ('for', 'hopes'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 1559}),
#  ('hopes', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'africans': 1559}),
#  ('of',
#   'africans'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('africans',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'black': 1559}),
#  ('and', 'black'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'people': 1559}),
#  ('black',
#   'people'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'everywhere': 1559}),
#  ('people',
#   'everywhere'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 1559}),
#  ('everywhere',
#   'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'must': 1559}),
#  ('must', 'thank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'god': 1559}),
#  ('thank', 'god'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'for': 3118}),
#  ('god', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'his': 1559, 'sparing': 1559}),
#  ('his',
#   'mercies'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 1559}),
#  ('mercies', 'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'mourn': 1559}),
#  ('we', 'mourn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('mourn', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'dead': 1559}),
#  ('the', 'dead'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'heroes': 1559}),
#  ('dead',
#   'heroes'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 1559}),
#  ('heroes', 'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'thank': 1559}),
#  ('we', 'thank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'god': 1559}),
#  ('for',
#   'sparing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'us': 1559}),
#  ('sparing', 'us'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 1559}),
#  ('us', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'see': 1559}),
#  ('to', 'see'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'his': 1559}),
#  ('see', 'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'glorious': 1559}),
#  ('his',
#   'glorious'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'dawn': 1559}),
#  ('glorious',
#   'dawn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('dawn', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'national': 1559}),
#  ('of',
#   'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'reconciliation': 1559}),
#  ('national',
#   'reconciliation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 1559}),
#  ('reconciliation',
#   'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'have': 1559}),
#  ('we', 'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'ordered': 1559, 'overcome': 1559}),
#  ('have',
#   'ordered'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'that': 1559}),
#  ('ordered',
#   'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'friday': 1559}),
#  ('that',
#   'friday'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'saturday': 1559}),
#  ('friday',
#   'saturday'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('saturday',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'sunday': 1559}),
#  ('and', 'sunday'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'be': 1559}),
#  ('sunday', 'be'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'national': 1559}),
#  ('be',
#   'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'days': 1559}),
#  ('national',
#   'days'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('days', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'prayer': 1559}),
#  ('of', 'prayer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'we': 1559}),
#  ('prayer', 'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'must': 1559}),
#  ('must', 'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'guidance': 1559}),
#  ('his',
#   'guidance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1559}),
#  ('guidance',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'do': 1559}),
#  ('to', 'do'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'our': 1559}),
#  ('do', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'duty': 1559}),
#  ('our', 'duty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 1559}),
#  ('duty', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'contribute': 1559}),
#  ('to',
#   'contribute'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 1559}),
#  ('contribute',
#   'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'quota': 1559}),
#  ('our', 'quota'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 1559}),
#  ('quota', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('the',
#   'building'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('building',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1559}),
#  ('of', 'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'corrective': 1559, 'great': 1559}),
#  ('a', 'great'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'nation': 3118}),
#  ('great',
#   'nation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'founded': 1559,
#               'so': 1559}),
#  ('nation',
#   'founded'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'on': 1559}),
#  ('founded', 'on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('on', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'concerted': 1559}),
#  ('the',
#   'concerted'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'efforts': 1559}),
#  ('concerted',
# ...
#  ('government',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'commander': 1559}),
#  ('and',
#   'commander'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1559}),
#  ('commander',
#   'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'chief': 1559}),
#  ('in', 'chief'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 1559}),
#  ('chief', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'air': 4677,
#               'army': 3118,
#               'naval': 4677,
#               'staff': 6236,
#               'the': 1559}),
#  ('forces', '2'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('2', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'retirement': 1559}),
#  ('the',
#   'retirement'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('retirement',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'general': 1559}),
#  ('gowon', 'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('from', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'armed': 1559}),
#  ('forces', 'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'his': 1559}),
#  ('in', 'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'present': 1559}),
#  ('his',
#   'present'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'rank': 1559}),
#  ('present',
#   'rank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('rank', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'general': 1559, 'major': 1559}),
#  ('general',
#   'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'full': 1559}),
#  ('with', 'full'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'benefits': 1559}),
#  ('full',
#   'benefits'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1559}),
#  ('benefits',
#   'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'recognition': 1559}),
#  ('in',
#   'recognition'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('recognition',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'his': 1559}),
#  ('of', 'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'choice': 1559, 'family': 1559, 'past': 1559}),
#  ('his', 'past'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'services': 1559}),
#  ('past',
#   'services'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1559}),
#  ('services',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('nation', '3'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'general': 1559}),
#  ('3', 'general'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'gowon': 1559}),
#  ('gowon', 'will'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'be': 1559}),
#  ('be', 'free'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 3118}),
#  ('free', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'pursue': 1559, 'return': 1559}),
#  ('country', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'soon': 1559}),
#  ('as', 'soon'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'as': 1559}),
#  ('soon', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'conditions': 1559}),
#  ('as',
#   'conditions'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'permit': 1559}),
#  ('conditions',
#   'permit'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'he': 1559}),
#  ('permit', 'he'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'will': 1559}),
#  ('he', 'will'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'be': 1559}),
#  ('to', 'pursue'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'any': 1559}),
#  ('pursue', 'any'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'legitimate': 1559}),
#  ('any',
#   'legitimate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'undertakings': 1559}),
#  ('legitimate',
#   'undertakings'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('undertakings',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'his': 1559}),
#  ('his', 'choice'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'in': 1559}),
#  ('choice', 'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'any': 1559}),
#  ('in', 'any'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'part': 1559}),
#  ('any', 'part'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 1559}),
#  ('part', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('country',
#   'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'personal': 1559}),
#  ('his',
#   'personal'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'safety': 1559}),
#  ('personal',
#   'safety'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('safety', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'freedom': 1559}),
#  ('and',
#   'freedom'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('freedom',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'those': 1559}),
#  ('and', 'those'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 1559}),
#  ('those', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'his': 1559}),
#  ('his', 'family'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'will': 1559}),
#  ('family',
#   'will'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'be': 1559}),
#  ('be',
#   'guaranteed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'4': 1559}),
#  ('guaranteed',
#   '4'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('4', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'following': 1559}),
#  ('following',
#   'members'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('forces', 'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'retired': 1559}),
#  ('are',
#   'retired'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'with': 1559}),
#  ('retired',
#   'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'immediate': 1559}),
#  ('with',
#   'immediate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'effect': 4677}),
#  ('immediate',
#   'effect'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'all': 1559,
#               'the': 1559,
#               'vice': 1559}),
#  ('effect',
#   'vice'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'admiral': 1559}),
#  ('vice',
#   'admiral'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'jea': 1559}),
#  ('admiral',
#   'jea'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'wey': 1559}),
#  ('jea', 'wey'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'chief': 1559}),
#  ('wey', 'chief'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 1559}),
#  ('of', 'staff'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'army': 1559, 'shq': 1559, 'supreme': 3118}),
#  ('staff',
#   'supreme'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'hq': 3118}),
#  ('supreme', 'hq'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'major': 3118}),
#  ('hq', 'major'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'general': 3118}),
#  ('general',
#   'hassan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'katsina': 1559}),
#  ('hassan',
#   'katsina'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'deputy': 1559}),
#  ('katsina',
#   'deputy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'chief': 1559}),
#  ('deputy',
#   'chief'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('general',
#   'david'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ejoor': 1559}),
#  ('david',
#   'ejoor'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'chief': 1559}),
#  ('ejoor',
#   'chief'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('staff', 'army'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'rear': 1559}),
#  ('army', 'rear'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'admiral': 1559}),
#  ('rear',
#   'admiral'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'nelson': 1559}),
#  ('admiral',
#   'nelson'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'soroh': 1559}),
#  ('nelson',
#   'soroh'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'chief': 1559}),
#  ('soroh',
#   'chief'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('of', 'naval'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'staff': 4677}),
#  ('naval',
#   'staff'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'brigadier': 1559,
#               'mr': 1559,
#               'p': 1559}),
#  ('staff',
#   'brigadier'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ee': 1559}),
#  ('brigadier',
#   'ee'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ikwue': 1559}),
#  ('ee', 'ikwue'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'chief': 1559}),
#  ('ikwue',
#   'chief'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('of', 'air'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'staff': 4677}),
#  ('air', 'staff'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 1559, 'commodore': 1559, 'p': 1559}),
#  ('staff', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'all': 1559}),
#  ('and', 'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'other': 1559}),
#  ('all', 'other'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'officers': 1559}),
#  ('other',
#   'officers'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('officers',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('the', 'rank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 1559}),
#  ('of', 'major'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'general': 1559}),
#  ('general', 'or'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'equivalent': 1559}),
#  ('or',
#   'equivalent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('equivalent',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'above': 1559}),
#  ('and', 'above'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'alhaji': 1559}),
#  ('above',
#   'alhaji'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'kam': 1559}),
#  ('alhaji', 'kam'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'salem': 1559}),
#  ('kam', 'salem'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'inspector': 1559}),
#  ('salem',
#   'inspector'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'general': 1559}),
#  ('inspector',
#   'general'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 4677}),
#  ('of', 'police'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'chief': 1559, 'p': 4677}),
#  ('police',
#   'chief'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ta': 1559}),
#  ('chief', 'ta'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'fagbola': 1559}),
#  ('ta', 'fagbola'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'deputy': 1559}),
#  ('fagbola',
#   'deputy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'inspector': 1559}),
#  ('deputy',
#   'inspector'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'general': 1559}),
#  ('of', 'police5'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'also': 1559}),
#  ('police5',
#   'also'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'with': 1559}),
#  ('also', 'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'immediate': 1559}),
#  ('effect', 'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 1559}),
#  ('all', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'civil': 1559, 'present': 1559}),
#  ('the',
#   'present'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'military': 1559}),
#  ('present',
#   'military'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'governors': 1559}),
#  ('military',
#   'governors'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559}),
#  ('governors',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1559}),
#  ('the',
#   'administrator'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('administrator',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'east': 1559}),
#  ('of', 'east'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'central': 1559}),
#  ('east',
#   'central'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'p': 1559,
#               'state': 1559}),
#  ('central',
#   'state'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'have': 1559}),
#  ('state', 'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'been': 1559}),
#  ('have', 'been'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'made': 1559, 'relieved': 1559}),
#  ('been',
#   'relieved'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1559}),
#  ('relieved',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'their': 3118}),
#  ('of', 'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'appointments': 3118}),
#  ('their',
#   'appointments'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1559,
#               'with': 1559}),
#  ('appointments',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'retired': 1559}),
#  ('and',
#   'retired'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'6': 1559}),
#  ('retired', '6'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'as': 1559}),
#  ('6', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'you': 1559}),
#  ('as', 'you'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'are': 1559}),
#  ('you', 'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'already': 1559}),
#  ('are',
#   'already'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'aware': 1559}),
#  ('already',
#   'aware'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'new': 1559}),
#  ...}

# %%
# convert the word occurance scores into probabilities
for words_train in word_model:
    total_count = float(sum(word_model[words_train].values()))
    for word_test in word_model[words_train]:
        word_model[words_train][word_test] /= total_count

# %%
dict(word_model['patience', 'sacrifice'])
# Out:
# {'loyalty': 1.0}

# %%
dict(word_model['us', 'as'])
# Out:
# {'we': 1.0}

# %%
dict(word_model['share', 'the'])
# Out:
# {'victory': 1.0}

# %%
dict(word_model['should', 'not'])
# Out:
# {'be': 1.0}

# %%
dict(word_model['central','state'])
# Out:
# {'have': 1.0}

# %%
dict(word_model['present',
  'military'])
# Out:
# {'governors': 1.0}

# %%
dict(word_model['appointments',
  'and'])
# Out:
# {'retired': 1.0}
